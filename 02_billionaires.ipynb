# %% [markdown]
# # Homework 5, Part 2: Answer questions with pandas
#
# **Use the Excel file to answer the following questions.** This is a little more typical of what your data exploration will look like with pandas.

# %% [markdown]
# ## 0) Setup
#
# Import pandas **with the correct name** .

# %%
import pandas as pd

# %% [markdown]
# ## 1) Reading in an Excel file
#
# Use pandas to read in the `richpeople.xlsx` Excel file, saving it as a variable with the name we'll always use for a dataframe.
#
# > **TIP:** You will use `read_excel` instead of `read_csv`. Trying `read_excel` the first time will probably not work, you'll get an error message. Be sure to read the error carefully: *you probably need to install a new library before it will work, and the error tells you what the library is named*.

# %%
pd.read_excel("richpeople.xlsx")


# "C:\Users\nao22\Foundation\05_homework\richpeople.xlsx"
#  encoding= 'unicode_escape'
# Out:
#       year                          name  rank           citizenship  \
# 0     2014          A. Jerrold Perenchio   663         United States
# 1     2014            Abdulla Al Futtaim   687  United Arab Emirates
# 2     2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates
# 3     2014             Abdullah Al Rajhi   731          Saudi Arabia
# 4     2014              Abdulsamad Rabiu  1372               Nigeria
# ...    ...                           ...   ...                   ...
# 1648  2014                     Zhu Yicai  1154                 China
# 1649  2014                 Ziyad Manasir   609                Russia
# 1650  2014            Ziyaudin Magomedov  1372                Russia
# 1651  2014                  Zong Qinghou    94                 China
# 1652  2014            Zygmunt Solorz-Zak   446                Poland
#
#      countrycode  networthusbillion   selfmade              typeofwealth  \
# ...

# %%
# !pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\nao22\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
df = pd.read_excel("richpeople.xlsx")
# 1653 rows × 30 columns

# %% [markdown]
# ## 2) Checking your data
#
# Display the number of rows and columns in your data. Also display the names and data types of each column.

# %%
df = pd.read_excel("richpeople.xlsx")
# 1653 rows × 30 columns

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1650, 1651, 1652], dtype=int64)

# %%
df.columns.values
# Out:
# array(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance',
#        'sector', 'company', 'companytype', 'relationshiptocompany',
#        'foundingdate', 'gdpcurrentus', 'sourceofwealth', 'notes',
#        'notes2', 'source', 'source_2', 'source_3', 'source_4'],
#       dtype=object)

# %% [markdown]
# ## 3) Who are the top 10 richest billionaires? Use the `networthusbillion` column.

# %%
df.sort_values('networthusbillion', ascending = False).head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 184   2014        Bill Gates     1  United States         USA
# 226   2014  Carlos Slim Helu     2         Mexico         MEX
# 79    2014    Amancio Ortega     3          Spain         ESP
# 1562  2014    Warren Buffett     4  United States         USA
# 862   2014     Larry Ellison     5  United States         USA
# 339   2014        David Koch     6  United States         USA
# 247   2014      Charles Koch     6  United States         USA
# 1364  2014   Sheldon Adelson     8  United States         USA
# 280   2014    Christy Walton     9  United States         USA
# 724   2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 184                76.0  self-made       founder non-finance    male  58.0
# 226                72.0  self-made  privatized and resources    male  74.0
# ...

# %% [markdown]
# ## 4) How many male billionaires are there compared to the number of female billionares? What percent is that? Do they have a different average wealth?
#
# > **TIP:** The last part uses `groupby`, but the count/percent part does not.
# > **TIP:** When I say "average," you can pick what kind of average you use.

# %%
df.gender.value_counts()
# Out:
# male      1473
# female     180
# Name: gender, dtype: int64

# %%
df.tail()
# there are 1653 billionares
# Out:
#       year                name  rank citizenship countrycode  \
# 1648  2014           Zhu Yicai  1154       China         CHN
# 1649  2014       Ziyad Manasir   609      Russia         RUS
# 1650  2014  Ziyaudin Magomedov  1372      Russia         RUS
# 1651  2014        Zong Qinghou    94       China         CHN
# 1652  2014  Zygmunt Solorz-Zak   446      Poland         POL
#
#       networthusbillion   selfmade              typeofwealth gender   age  \
# 1648                1.5  self-made         self-made finance   male  49.0
# 1649                2.8  self-made  privatized and resources   male  48.0
# 1650                1.2  self-made  privatized and resources   male  45.0
# 1651               11.6  self-made       founder non-finance   male  68.0
# 1652                3.5  self-made       founder non-finance   male  57.0
#
#       ... relationshiptocompany foundingdate gdpcurrentus   sourceofwealth  \
# ...

# %%
### This part is too redundant. where should I use groupby???


gender_male = df[df.gender == 'male']
gender_female = df[df.gender == 'female']

gender_male.gender.value_counts()
# male    1473
gender_female.gender.value_counts()
# female    180

"There are 1473 male billionares and they account for", round(1473/1653*100), "% of total."
# Out:
# ('There are 1473 male billionares and they account for', 89, '% of total.')

# %%
"There are 180 male billionares and they account for", round(180/1653*100), "% of total."
# Out:
# ('There are 180 male billionares and they account for', 11, '% of total.')

# %%
df_male = df[df.gender == 'male'] 
df_female = df[df.gender == 'female']


df_male.networthusbillion.median()
# 2.1 billion

df_female.networthusbillion.median()
# 2.3 billion
# Out:
# 2.3

# %% [markdown]
# ## 5) What is the most common source/type of wealth? Is it different between males and females?
#
# > **TIP:** You know how to `groupby` and you know how to count how many times a value is in a column. Can you put them together???
# > **TIP:** Use percentages for this, it makes it a lot more readable.

# %%
df.typeofwealth.value_counts().head(1)
# inherited    506

df_male.typeofwealth.value_counts().head(1)
# founder non-finance         446


df_female.typeofwealth.value_counts().head(1)

# inherited                   142


# df['percent'] = (df[''] / df['typeofwealth'].sum()) * 100


df.typeofwealth.value_counts().head(1)
# Out:
# inherited    506
# Name: typeofwealth, dtype: int64

# %%
df_female.typeofwealth.value_counts()

# inherited                   142
# founder non-finance          21
# self-made finance             6
# executive                     6
# privatized and resources      5
# Name: typeofwealth, dtype: int64

# %% [markdown]
# ## 6) What companies have the most billionaires? Graph the top 5 as a horizontal bar graph.
#
# > **TIP:** First find the answer to the question, then just try to throw `.plot()` on the end
# >
# > **TIP:** You can use `.head()` on *anything*, not just your basic `df`
# >
# > **TIP:** You might feel like you should use `groupby`, but don't! There's an easier way to count.
# >
# > **TIP:** Make the largest bar be at the top of the graph
# >
# > **TIP:** If your chart seems... weird, think about where in the process you're sorting vs using `head`

# %%
df_top_age = df.sort_values(by = 'age', ascending = False).head(5)

df_top_age.sort_values('age').plot.barh(x = 'name', y=['age'], xlim=[50,100], figsize=(20,5))
# Out:
# <AxesSubplot:ylabel='name'>

# %% [markdown]
# ## 7) How much money do these billionaires have in total?

# %%
df.networthusbillion.sum()
# Out:
# 6454.400000000001

# %% [markdown]
# ## 8) What are the top 10 countries with the most money held by billionaires?
#
# I am **not** asking which country has the most billionaires - this is **total amount of money per country.**
#
# > **TIP:** Think about it in steps - "I want them organized by country," "I want their net worth," "I want to add it all up," and "I want 10 of them." Just chain it all together.

# %%
top_country = df.groupby('countrycode').networthusbillion.sum().sort_values().tail(10)

top_country


#ASK: how to print this descending order
# Out:
# countrycode
# GBR     152.0
# ITA     158.1
# IND     191.9
# BRA     192.2
# HKG     213.7
# FRA     235.3
# CHN     375.8
# DEU     401.4
# RUS     422.5
# USA    2322.4
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## 9) How old is an average billionaire? How old are self-made billionaires  vs. non self-made billionaires?

# %%
df.age.mean()
# Out:
# 63.34213836477988

# %%
#self-made, inherited, NAAN
self_made = df[df.selfmade == 'self-made']
self_made
inherited = df[df.selfmade != 'self-made']
inherited

self_made.age.mean()
# 62.62589928057554 yrs old

inherited.age.mean()
# 65.00836820083683 yrs old
# Out:
# 65.00836820083683

# %% [markdown]
# ## 10) Who are the youngest billionaires? Who are the oldest? Make a graph of the distribution of ages.
#
# > **TIP:** You use `.plot()` to graph values in a column independently, but `.hist()` to draw a [histogram](https://www.mathsisfun.com/data/histograms.html) of the distribution of their values

# %%
df.age.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df.sort_values('age').head(1)
# Out:
#       year         name  rank citizenship countrycode  networthusbillion  \
# 1172  2014  Perenna Kei  1284   Hong Kong         HKG                1.3
#
#        selfmade typeofwealth  gender   age  ... gdpcurrentus sourceofwealth  \
# 1172  inherited    inherited  female  24.0  ...          NaN    real estate
#
#                       notes  notes2                                    source  \
# 1172  inherited from father     NaN  http://en.wikipedia.org/wiki/Perenna_Kei
#
#                                                source_2 source_3 source_4  \
# 1172  http://www.loganestate.com/en/about.aspx?ftid=294      NaN      NaN
#
#      netwirth_sum_country networth_sum_country
# 1172                  NaN                  NaN
#
# [1 rows x 32 columns]

# %%
df.sort_values('age', ascending = False).head(1)
# Out:
#      year                    name  rank    citizenship countrycode  \
# 343  2014  David Rockefeller, Sr.   580  United States         USA
#
#      networthusbillion   selfmade typeofwealth gender   age  ... gdpcurrentus  \
# 343                2.9  inherited    inherited   male  98.0  ...          NaN
#
#     sourceofwealth                                              notes  notes2  \
# 343   oil, banking  family made most of fortune in the late 19th a...     NaN
#
#                                              source  \
# 343  http://en.wikipedia.org/wiki/David_Rockefeller
#
#                                       source_2  \
# 343  http://en.wikipedia.org/wiki/Standard_Oil
#
#                                             source_3 source_4  \
# 343  http://en.wikipedia.org/wiki/Rockefeller_family      NaN
#
#     netwirth_sum_country networth_sum_country
# 343                  NaN                  NaN
#
# [1 rows x 32 columns]

# %% [markdown]
# ## 11) Make a scatterplot of net worth compared to age

# %%
# DataFrame.plot.scatter(x, y, s=None, c=None, **kwargs)[source]

df.plot.scatter(x= 'age', y='networthusbillion')

#ASK: how to solve the dense area of the scatterplot
# Out:
# <AxesSubplot:xlabel='age', ylabel='networthusbillion'>

# %% [markdown]
# ## 13) Make a bar graph of the wealth of the top 10 richest billionaires
#
# > **TIP:** When you make your plot, you'll need to set the `x` and `y` or else your chart will look _crazy_
# >
# > **TIP:** x and y might be the opposite of what you expect them to be

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df.sort_values('networthusbillion', ascending = False).head(10).plot.bar(x='name', y='networthusbillion', title ="top 10 richest billionaires")
# Out:
# <AxesSubplot:title={'center':'top 10 richest billionaires'}, xlabel='name'>
